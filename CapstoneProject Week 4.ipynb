# %% [markdown]
# ![image.png](attachment:984072c3-ad2e-4ef9-a2f7-baaad310c021.png)
# ![image.png](attachment:366a45f6-9598-4b3b-9af4-dea959566860.png)

# %% [markdown]
# ![image.png](attachment:3e881b6f-2db4-4b81-8e4b-35351674976b.png)

# %% [markdown]
# ![image.png](attachment:42a8f143-b695-4aa0-96e4-c088d4c12e22.png)
